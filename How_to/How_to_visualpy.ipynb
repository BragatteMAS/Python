# %% [markdown]
# How to Visualpython
#
# @Bragatte 202305021637 [REF](https://www.visualpython.ai/)actor

# %%
pip install visualpython
# Out:
# Collecting visualpython
#   Downloading visualpython-2.3.6-py3-none-any.whl (15.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.1/15.1 MB 12.4 MB/s eta 0:00:0000:0100:01
# Installing collected packages: visualpython
# Successfully installed visualpython-2.3.6
# Note: you may need to restart the kernel to use updated packages.

# %%
# !visualpy install
# Out:
# Package install command: pip
# ============================================================================================
# Copy visualpyhthon extension files ...
# --------------------------------------------------------------------------------------------
# Source Dir :  /home/marcelo/anaconda3/lib/python3.9/site-packages/visualpython
# Target Dir :  /home/marcelo/anaconda3/share/jupyter/nbextensions/visualpython
# ============================================================================================
# Enabling notebook extension visualpython/visualpython...
#       - Validating: OK

# %%
# !visualpy -v
# Out:
# Package install command: pip
# Visual Python 2.3.6

# %%
# Visual Python: Data Analysis > Import
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
# Visual Python: Data Analysis > File
data = pd.read_csv('https://raw.githubusercontent.com/visualpython/visualpython/main/visualpython/data/sample_csv/iris.csv')
data
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
# Visual Python: Data Analysis > Subset
data.loc[(data['variety'] == 'Setosa')&(data['sepal.length'] < 5), ['variety','sepal.length','petal.length']]
# Out:
#    variety  sepal.length  petal.length
# 1   Setosa           4.9           1.4
# 2   Setosa           4.7           1.3
# 3   Setosa           4.6           1.5
# 6   Setosa           4.6           1.4
# 8   Setosa           4.4           1.4
# 9   Setosa           4.9           1.5
# 11  Setosa           4.8           1.6
# 12  Setosa           4.8           1.4
# 13  Setosa           4.3           1.1
# 22  Setosa           4.6           1.0
# 24  Setosa           4.8           1.9
# 29  Setosa           4.7           1.6
# 30  Setosa           4.8           1.6
# 34  Setosa           4.9           1.5
# 37  Setosa           4.9           1.4
# 38  Setosa           4.4           1.3
# 41  Setosa           4.5           1.3
# 42  Setosa           4.4           1.3
# 45  Setosa           4.8           1.4
# 47  Setosa           4.6           1.4

# %%
# Visual Python: Visualization > Seaborn
sns.lineplot(data=data)
plt.show()

# %%
# Visual Python: Machine Learning > Data Split
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(data[['sepal.length', 'sepal.width', 'petal.length', 'petal.width']], data['variety'])

# %%
# Visual Python: Machine Learning > Classifier
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier()

# %%
# Visual Python: Machine Learning > Fit/Predict
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
# Visual Python: Machine Learning > Fit/Predict
pred = model.predict(X_test)
pred
# Out:
# array(['Setosa', 'Setosa', 'Virginica', 'Virginica', 'Setosa',
#        'Versicolor', 'Versicolor', 'Virginica', 'Virginica', 'Versicolor',
#        'Virginica', 'Virginica', 'Setosa', 'Versicolor', 'Setosa',
#        'Versicolor', 'Virginica', 'Setosa', 'Virginica', 'Virginica',
#        'Versicolor', 'Versicolor', 'Virginica', 'Setosa', 'Virginica',
#        'Versicolor', 'Versicolor', 'Setosa', 'Virginica', 'Virginica',
#        'Setosa', 'Virginica', 'Setosa', 'Virginica', 'Setosa', 'Setosa',
#        'Setosa', 'Setosa'], dtype=object)

# %%
# Visual Python: Machine Learning > Evaluation
from sklearn import metrics

# %%
# Visual Python: Machine Learning > Evaluation
from sklearn import metrics

# %%
# Visual Python: Machine Learning > Evaluation
# Confusion Matrix
pd.crosstab(y_test, pred, margins=True)
# Out:
# col_0       Setosa  Versicolor  Virginica  All
# variety
# Setosa          14           0          0   14
# Versicolor       0           7          0    7
# Virginica        0           2         15   17
# All             14           9         15   38

# %%
# Visual Python: Machine Learning > Evaluation
# Classification report
print(metrics.classification_report(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#       Setosa       1.00      1.00      1.00        14
#   Versicolor       0.78      1.00      0.88         7
#    Virginica       1.00      0.88      0.94        17
#
#     accuracy                           0.95        38
#    macro avg       0.93      0.96      0.94        38
# weighted avg       0.96      0.95      0.95        38
