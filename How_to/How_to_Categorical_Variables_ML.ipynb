# %% [markdown]
# <a href="https://colab.research.google.com/github/BragatteMAS/Python/blob/master/How_to/How_to_Categorical_Variables_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # How_to_Categorical_Variables_ML
#
# [REF](https://www.youtube.com/watch?v=ZPTAeXfaZ4g)actor from
#
# [Enem_datasets](https://archive.org/download/microdados_enem_2019_por_estados) by
#
# @Bragatte  210612

# %%
import pandas as pd

# %%
df_enem = pd.read_csv("https://archive.org/download/microdados_enem_2019_por_estados/microdados_enem_AM_2019.csv")

# %%
df_enem.head()
# Out:
#    NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA  ... Q023  Q024 Q025
# 0  190001006769    2019                  1302603  ...    A     A    A
# 1  190001007816    2019                  1302603  ...    A     A    A
# 2  190001013052    2019                  1302603  ...    A     A    B
# 3  190001015529    2019                  1302603  ...    A     A    A
# 4  190001025124    2019                  1302405  ...    A     A    A
#
# [5 rows x 136 columns]

# %%
df_enem.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118087 entries, 0 to 118086
# Data columns (total 136 columns):
#  #   Column                       Dtype
# ---  ------                       -----
#  0   NU_INSCRICAO                 int64
#  1   NU_ANO                       int64
#  2   CO_MUNICIPIO_RESIDENCIA      int64
#  3   NO_MUNICIPIO_RESIDENCIA      object
#  4   CO_UF_RESIDENCIA             int64
#  5   SG_UF_RESIDENCIA             object
#  6   NU_IDADE                     int64
#  7   TP_SEXO                      object
#  8   TP_ESTADO_CIVIL              int64
#  9   TP_COR_RACA                  int64
#  10  TP_NACIONALIDADE             int64
#  11  CO_MUNICIPIO_NASCIMENTO      float64
#  12  NO_MUNICIPIO_NASCIMENTO      object
#  13  CO_UF_NASCIMENTO             float64
#  14  SG_UF_NASCIMENTO             object
#  15  TP_ST_CONCLUSAO              int64
#  16  TP_ANO_CONCLUIU              int64
#  17  TP_ESCOLA                    int64
# ...

# %% [markdown]
# ## Select especific tipe of columns

# %%
df_enem.select_dtypes(include="object").describe()
# Out:
#        NO_MUNICIPIO_RESIDENCIA SG_UF_RESIDENCIA TP_SEXO  ...    Q023    Q024    Q025
# count                   118087           118087  118087  ...  118087  118087  118087
# unique                      62                1       2  ...       2       5       2
# top                     Manaus               AM       F  ...       A       A       B
# freq                     85305           118087   68510  ...  108498   75502   63760
#
# [4 rows x 41 columns]

# %% [markdown]
# ## *Substitution*

# %%
df_enem_cats = df_enem.select_dtypes(include="object")

# %%
df_enem_cats.describe()
# Out:
#        NO_MUNICIPIO_RESIDENCIA SG_UF_RESIDENCIA TP_SEXO  ...    Q023    Q024    Q025
# count                   118087           118087  118087  ...  118087  118087  118087
# unique                      62                1       2  ...       2       5       2
# top                     Manaus               AM       F  ...       A       A       B
# freq                     85305           118087   68510  ...  108498   75502   63760
#
# [4 rows x 41 columns]

# %% [markdown]
# ## One-Hot Encoding

# %%
# !pip install category_encoders
# Out:
# ...
#      |████████████████████████████████| 81kB 5.2MB/s
# ...

# %%
import category_encoders as ce
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
df_enem['TP_SEXO']
# Out:
# 0         F
# 1         F
# 2         F
# 3         M
# 4         F
#          ..
# 118082    M
# 118083    M
# 118084    F
# 118085    F
# 118086    M
# Name: TP_SEXO, Length: 118087, dtype: object

# %%
from category_encoders.one_hot import OneHotEncoder

# %%
one_hot_enc = OneHotEncoder(cols=['TP_SEXO']) #create two new columns TP_SEXO_* 1 and 2

# %%
df_enem_cats_ohe = one_hot_enc.fit_transform(df_enem_cats)
# Out:
# /usr/local/lib/python3.7/dist-packages/category_encoders/utils.py:21: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   elif pd.api.types.is_categorical(cols):

# %% [markdown]
# ## Ordinal Encoding

# %%
 from category_encoders.one_hot import OneHotEncoder, OrdinalEncoder

# %%
df_enem_cats.columns
# Out:
# Index(['NO_MUNICIPIO_RESIDENCIA', 'SG_UF_RESIDENCIA', 'TP_SEXO',
#        'NO_MUNICIPIO_NASCIMENTO', 'SG_UF_NASCIMENTO', 'NO_MUNICIPIO_ESC',
#        'SG_UF_ESC', 'NO_MUNICIPIO_PROVA', 'SG_UF_PROVA', 'TX_RESPOSTAS_CN',
#        'TX_RESPOSTAS_CH', 'TX_RESPOSTAS_LC', 'TX_RESPOSTAS_MT',
#        'TX_GABARITO_CN', 'TX_GABARITO_CH', 'TX_GABARITO_LC', 'TX_GABARITO_MT',
#        'Q001', 'Q002', 'Q003', 'Q004', 'Q006', 'Q007', 'Q008', 'Q009', 'Q010',
#        'Q011', 'Q012', 'Q013', 'Q014', 'Q015', 'Q016', 'Q017', 'Q018', 'Q019',
#        'Q020', 'Q021', 'Q022', 'Q023', 'Q024', 'Q025'],
#       dtype='object')

# %%
ord_enc = OrdinalEncoder(cols=[ 'Q001', 'Q002', 'Q003', 'Q004', 'Q006', 'Q007', 'Q008', 'Q009', 'Q010',
       'Q011', 'Q012', 'Q013', 'Q014', 'Q015', 'Q016', 'Q017', 'Q018', 'Q019',
       'Q020', 'Q021', 'Q022', 'Q023', 'Q024', 'Q025'] ) #columns to change to ordinal

# %%
ord_enc.fit_transform(df_enem_cats_ohe) #remember to set for controled table
# Out:
# /usr/local/lib/python3.7/dist-packages/category_encoders/utils.py:21: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   elif pd.api.types.is_categorical(cols):
#        NO_MUNICIPIO_RESIDENCIA SG_UF_RESIDENCIA  TP_SEXO_1  ...  Q023 Q024 Q025
# 0                       Manaus               AM          1  ...     1    1    1
# 1                       Manaus               AM          1  ...     1    1    1
# 2                       Manaus               AM          1  ...     1    1    2
# 3                       Manaus               AM          0  ...     1    1    1
# 4                       Lábrea               AM          1  ...     1    1    1
# ...                        ...              ...        ...  ...   ...  ...  ...
# 118082                   Coari               AM          0  ...     1    1    1
# 118083                  Manaus               AM          0  ...     1    2    2
# ...
