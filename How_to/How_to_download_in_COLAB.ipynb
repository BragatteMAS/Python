# %% [markdown]
# <a href="https://colab.research.google.com/github/BragatteMAS/Python/blob/master/How_to/How_to_download_in_COLAB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Download manually

# %% [markdown]
# Create file from COLAB

# %%
# !mkdir -p "/content/drive/MyDrive/9.Colab Notebooks/RedeAnaliseCOVID-19/Codes/vacinas"

# %% [markdown]
# Save download from URL direct in googledrive | COLAB
#
# Put the url right after de path - if the path are not inform will be a temp file

# %%
# !wget -P "/content/drive/MyDrive/9.Colab Notebooks/RedeAnaliseCOVID-19/Codes/vacinas" https://s3-sa-east-1.amazonaws.com/ckan.saude.gov.br/PNI/vacina/uf/2021-04-28/uf%3DRS/part-00000-7ab10ee1-6a0f-4ed9-b84c-9afb98b4efc2.c000.csv

# %%
#rs_vac = pd.read_csv('/content/drive/MyDrive/9.Colab Notebooks/RedeAnaliseCOVID-19/Codes/vacinas/RS_vacinas.csv', sep=';')
#rs_vac.head(10)

# %% [markdown]
# Download to tempfile

# %%
# !wget -p https://s3-sa-east-1.amazonaws.com/ckan.saude.gov.br/PNI/vacina/uf/2021-04-28/uf%3DRS/part-00000-7ab10ee1-6a0f-4ed9-b84c-9afb98b4efc2.c000.csv
# Out:
# --2021-04-28 20:26:39--  https://s3-sa-east-1.amazonaws.com/ckan.saude.gov.br/PNI/vacina/uf/2021-04-28/uf%3DRS/part-00000-7ab10ee1-6a0f-4ed9-b84c-9afb98b4efc2.c000.csv
# Resolving s3-sa-east-1.amazonaws.com (s3-sa-east-1.amazonaws.com)... 52.95.165.80
# Connecting to s3-sa-east-1.amazonaws.com (s3-sa-east-1.amazonaws.com)|52.95.165.80|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1711005641 (1.6G) [text/csv]
# Saving to: ‘s3-sa-east-1.amazonaws.com/ckan.saude.gov.br/PNI/vacina/uf/2021-04-28/uf=RS/part-00000-7ab10ee1-6a0f-4ed9-b84c-9afb98b4efc2.c000.csv’
#
# s3-sa-east-1.amazon 100%[===================>]   1.59G  24.6MB/s    in 68s
#
# 2021-04-28 20:27:47 (24.1 MB/s) - ‘s3-sa-east-1.amazonaws.com/ckan.saude.gov.br/PNI/vacina/uf/2021-04-28/uf=RS/part-00000-7ab10ee1-6a0f-4ed9-b84c-9afb98b4efc2.c000.csv’ saved [1711005641/1711005641]
#
# FINISHED --2021-04-28 20:27:47--
# Total wall clock time: 1m 8s
# Downloaded: 1 files, 1.6G in 1m 8s (24.1 MB/s)

# %%
import pandas as pd

# %%
rs_vac = pd.read_csv('/content/s3-sa-east-1.amazonaws.com/ckan.saude.gov.br/PNI/vacina/uf/2021-04-28/uf=RS/part-00000-7ab10ee1-6a0f-4ed9-b84c-9afb98b4efc2.c000.csv', sep=";")
rs_vac.head(10)
# Out:
#                                  document_id  ... id_sistema_origem
# 0  a8b602f5-ddb2-4e25-a4ce-c83c4f9b2320-i0b0  ...             16341
# 1  21a160a7-b513-4b63-a6bf-6544376a8a80-i0b0  ...             16341
# 2  0ae299b9-cff4-4bd2-bdfd-09d47514b97c-i0b0  ...             16341
# 3  31b8095d-e8cb-4825-b43a-c46166952270-i0b0  ...             16341
# 4  c36faa51-f831-4633-9677-fd432ffccb84-i0b0  ...             16341
# 5  579fc2ed-fc00-4277-b961-464994035a29-i0b0  ...             16341
# 6  6d59cf70-8b9a-45e5-845a-11703bcc7e05-i0b0  ...             16341
# 7  942040d9-b757-4133-a65b-01df8d582953-i0b0  ...             16341
# 8  1db54db4-be18-4607-a2fb-6c15b8d5aaad-i0b0  ...             16341
# 9  f18f0790-f2ad-481c-859f-a304e0ee90c5-i0b0  ...             16341
#
# [10 rows x 34 columns]

# %% [markdown]
# [REF](https://www.youtube.com/watch?v=sbOnV78uoys)actor by
#
# @author: bragatte

# %% [markdown]
# # Auto Download

# %% [markdown]
# ## Files with hiding link

# %% [markdown]
# 1. Check site with F12
# 2. Network option to redirect link

# %% [markdown]
# ![link.png](data:image/png;base64,...)

# %%
# !wget -p https://mobileapps.saude.gov.br/esus-vepi/files/unAFkcaNDeXajurGB7LChj8SgQYS2ptm/90990a893a2cc6e2b617f5437e9cdee6_HIST_PAINEL_COVIDBR_11mai2021.csv
# Out:
# --2021-05-12 06:27:44--  https://mobileapps.saude.gov.br/esus-vepi/files/unAFkcaNDeXajurGB7LChj8SgQYS2ptm/90990a893a2cc6e2b617f5437e9cdee6_HIST_PAINEL_COVIDBR_11mai2021.csv
# Resolving mobileapps.saude.gov.br (mobileapps.saude.gov.br)... 54.232.19.203, 18.229.206.140, 54.232.24.5
# Connecting to mobileapps.saude.gov.br (mobileapps.saude.gov.br)|54.232.19.203|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 204761809 (195M) [text/csv]
# Saving to: ‘mobileapps.saude.gov.br/esus-vepi/files/unAFkcaNDeXajurGB7LChj8SgQYS2ptm/90990a893a2cc6e2b617f5437e9cdee6_HIST_PAINEL_COVIDBR_11mai2021.csv’
#
# mobileapps.saude.go 100%[===================>] 195.28M  19.4MB/s    in 11s
#
# 2021-05-12 06:27:58 (17.0 MB/s) - ‘mobileapps.saude.gov.br/esus-vepi/files/unAFkcaNDeXajurGB7LChj8SgQYS2ptm/90990a893a2cc6e2b617f5437e9cdee6_HIST_PAINEL_COVIDBR_11mai2021.csv’ saved [204761809/204761809]
#
# FINISHED --2021-05-12 06:27:58--
# Total wall clock time: 13s
# ...

# %% [markdown]
# ## Files without link

# %% [markdown]
# 1. Selenium with chrome

# %%
# !pip install selenium
# !apt-get update
# !apt install chromium-chromedriver
# Out:
# ...
#      |████████████████████████████████| 911kB 5.0MB/s
# ...
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease
# Ign:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Ign:3 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:5 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Hit:6 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu bionic InRelease
# Hit:8 http://security.ubuntu.com/ubuntu bionic-security InRelease
# Hit:9 http://archive.ubuntu.com/ubuntu bionic-updates InRelease
# Hit:10 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Hit:11 http://archive.ubuntu.com/ubuntu bionic-backports InRelease
# ...

# %%
from selenium import webdriver

# %%
#chrome options - set your browser
chrome_options = webdriver.ChromeOptions()

# %%
#settings for chrome
chrome_options.add_argument('--headless')
chrome_options.add_argument('--no-sandbox')
chrome_options.add_argument('--disable-dev-shm-usage')

# %%
#Call settings
wd_chrome = webdriver.Chrome(chrome_options=chrome_options)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: use options instead of chrome_options
#   """Entry point for launching an IPython kernel.

# %%
# site acess with Xpath (Xml path) link for selenium
wd_chrome.get('https://covid.saude.gov.br')

# %% [markdown]
# ![Screenshot_2.png](data:image/png;base64,...)

# %%
csv_button = wd_chrome.find_element_by_xpath('/html/body/app-root/ion-app/ion-router-outlet/app-home/ion-content/div[1]/div[2]/ion-button')

# %%
# simulate click as navegation at site
csv_button.click()

# %% [markdown]
# Move file from temp to drive

# %%
# !mv '/content/HIST_PAINEL_COVIDBR_11mai2021.csv' '/content/drive/MyDrive'

# %% [markdown]
# [REF](https://www.youtube.com/watch?v=eHZ_d0bINkM)actor by
#
# @author: bragatte
